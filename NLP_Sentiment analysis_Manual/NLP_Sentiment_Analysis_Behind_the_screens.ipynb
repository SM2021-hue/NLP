# %% [markdown]
# ### Let's first categorize a tweet as posotive or negative
# * to classify, we need to train our classifier with some training sets.
# * Let's consider a positive tweet and a negative tweet.
# * IS the classifier with us on it?
# ##### Let's check!!
# * In a supervised machine learing problem, we have features (X) and output/target variable (Y). To get the output mapping, we pass the features through a prediction function Theta. Our goal is to get the best mapping which is earned by recucing the cost which is the difference between the true Y and the expected Y(aka Y-hat). SO we keep updating or tweaking our parameters(theta) to get the desired reduced cost (the least difference between Y and Y-hat)
#
# ![image.png](attachment:image.png)
#
#
#
# * Tweet_1: I am happy today because I did well and passed my test - If Positive Sentiment labeled 1
# * Tweet_2: I am sad that I didn't do well in the test and I failed - If Negative Sentiment labeled 0
# * To perform sentiment analysis on a tweet, you first have to represent the text (i.e. "I am happy today because I did well and passed my test ") as features, you then train your logistic regression classifier, and then you can use it to classify the text.
#
# * How do we go about doing this?
#  * Let's look at this:  I am happy today because I did well and passed my test
#  * Is it positive or negative?
# * I am using logistic regression classifier which assigns its observations from arbitary tweets to these two classes.
# * First, we will process raw tweets in our training set and extract useful features. Then we will train the logistic regression classifier while reducing the costs and finally we make our predictions.
#
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
